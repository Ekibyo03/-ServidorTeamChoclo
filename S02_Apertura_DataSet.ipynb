# %% [markdown]
# <a href="https://colab.research.google.com/github/Ekibyo03/-ServidorTeamChoclo/blob/main/S02_Apertura_DataSet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # INMERSIÓN DE DATOS CON PYTHON

# %% [markdown]
# #**INTEGRANTES**

# %% [markdown]
# - YUVITZA ESTHER GUERRERO CUADROS
# - FABRIZZIO MARCO CAPCHA CAMPOS
# - LUCIA SHANTALL OCHOA LUNA
# - PIERO BENFIELD'TS SANTOS RIVERA
# - ALDAIR FELIX CHAVARRIA NAVARRO

# %%
# prompt: importa los siguientes módulos con sus respectivos alias: pandas, matplotlib, seaborn, drive de google colab, warnings

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings("ignore")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #**PROBLEMA**
#
#
# ---

# %% [markdown]
# La importancia de reducir el riesgo crediticio ha llevado a una institución financiera alemana a buscar soluciones innovadoras. Como científicos de datos, hemos sido convocados para construir un modelo de machine learning preciso y confiable que sea capaz de evaluar con mayor precisión la probabilidad de incumplimiento crediticio de sus clientes.

# %%
pd.set_option('display.max_columns',None)
global df_banco, resultados

# %%
df_banco = pd.read_csv('/content/drive/MyDrive/Innovación/german_credit.csv')

# %%
df_banco.head()
# Out:
#    default account_check_status  duration_in_month  \
# 0        0               < 0 DM                  6
# 1        1    0 <= ... < 200 DM                 48
# 2        0  no checking account                 12
# 3        0               < 0 DM                 42
# 4        1               < 0 DM                 24
#
#                                       credit_history  \
# 0  critical account/ other credits existing (not ...
# 1           existing credits paid back duly till now
# 2  critical account/ other credits existing (not ...
# 3           existing credits paid back duly till now
# 4                    delay in paying off in the past
#
#                         purpose  credit_amount                      savings  \
# 0           domestic appliances           1169  unknown/ no savings account
# 1           domestic appliances           5951                 ... < 100 DM
# 2  (vacation - does not exist?)           2096                 ... < 100 DM
# ...

# %% [markdown]
# #**PROBLEMA**
#
#
# ---

# %% [markdown]
# 2. El Campeonato Sudamericano de Selecciones es uno de los torneos de fútbol más antiguos del mundo, donde equipos de Sudamérica compiten entre sí. Los datos proporcionados corresponden a partidos jugados desde 1916, incluyendo información detallada sobre los goles anotados en esos partidos. Este conjunto de datos contiene información sobre la fecha del partido, los equipos participantes (local y visitante), el equipo que marcó el gol, el jugador que anotó, el minuto en que se anotó el gol, y si fue un gol en propia puerta o un penal.

# %%
df_futbol = pd.read_csv('/content/drive/MyDrive/Innovación/goalscorers.csv')

# %%
df_futbol.head()
# Out:
#          date  home_team away_team       team            scorer  minute  \
# 0  1916-07-02      Chile   Uruguay    Uruguay   José Piendibene    44.0
# 1  1916-07-02      Chile   Uruguay    Uruguay  Isabelino Gradín    55.0
# 2  1916-07-02      Chile   Uruguay    Uruguay  Isabelino Gradín    70.0
# 3  1916-07-02      Chile   Uruguay    Uruguay   José Piendibene    75.0
# 4  1916-07-06  Argentina     Chile  Argentina     Alberto Ohaco     2.0
#
#    own_goal  penalty
# 0     False    False
# 1     False    False
# 2     False    False
# 3     False    False
# 4     False    False

# %% [markdown]
# #**PROBLEMA**
#
#
# ---

# %% [markdown]
# 3.El mercado bursátil global está compuesto por una vasta gama de empresas que operan en diferentes sectores e industrias. Las compañías con mayor capitalización bursátil a menudo lideran sus respectivos mercados y sectores, influyendo significativamente en las economías a nivel mundial. Este conjunto de datos proporciona información sobre las empresas con la mayor capitalización de mercado, incluyendo su ranking, nombre, capitalización de mercado, símbolo de acciones, país de origen, sector e industria.

# %%
df_Empre = pd.read_csv('/content/drive/MyDrive/Innovación/Top 1000 technology companies.csv')

# %%
df_Empre.head()
# Out:
#    Ranking                                            Company Market Cap  \
# 0        1                                         Apple Inc.   $2.866 T
# 1        2                              Microsoft Corporation   $2.755 T
# 2        3                                 Nvidia Corporation   $1.186 T
# 3        4                                      Broadcom Inc.  $495.95 B
# 4        5  Taiwan Semiconductor Manufacturing Company Lim...  $487.64 B
#
#   Stock        Country      Sector                 Industry
# 0  AAPL  United States  Technology     Consumer Electronics
# 1  MSFT  United States  Technology  Software—Infrastructure
# 2  NVDA  United States  Technology           Semiconductors
# 3  AVGO  United States  Technology           Semiconductors
# 4  2330         Taiwan  Technology           Semiconductors

# %% [markdown]
# #**PROBLEMA**
#
# ---

# %% [markdown]
# El objetivo principal es predecir la edad del abulón a partir de las variables disponibles sin tener que contar los anillos físicamente. Sin embargo, la principal problemática radica en la complejidad de construir un modelo de predicción preciso debido a la naturaleza no lineal de la relación entre las características del abulón y su edad. Además, la variable objetivo (el número de anillos) es discreta, lo que hace que la predicción sea un problema de clasificación ordinal, una tarea más compleja que una simple clasificación o regresión.

# %%
df_UCIml = pd.read_csv('/content/drive/MyDrive/Innovación/UCI table.csv')

# %%
df_UCIml.head()
# Out:
#    Unnamed: 0                          Name    Data Types  \
# 0           1                       Abalone  Multivariate
# 1           2                         Adult  Multivariate
# 2           3                     Annealing  Multivariate
# 3           4  Anonymous Microsoft Web Data           NaN
# 4           5                    Arrhythmia  Multivariate
#
#           Default Task             Attribute Types  Number of Instances  \
# 0       Classification  Categorical, Integer, Real                 4177
# 1       Classification        Categorical, Integer                48842
# 2       Classification  Categorical, Integer, Real                  798
# 3  Recommender Systems                 Categorical                37711
# 4       Classification  Categorical, Integer, Real                  452
#
#    Number of Attributes    Year  Sample size
# 0                   8.0  1995.0        Large
# 1                  14.0  1996.0  Extra Large
# ...

# %% [markdown]
# # PROBLEMA

# %% [markdown]
# La mortalidad infantil y materna son desafíos globales reflejados en los Objetivos de Desarrollo Sostenible de la ONU, que buscan eliminar las muertes evitables de recién nacidos y niños menores de 5 años, así como reducir significativamente la mortalidad materna para el año 2030. A pesar de los esfuerzos, un gran número de muertes infantiles y maternas ocurren en entornos con bajos recursos, y muchas de ellas son prevenibles.

# %%
df_fetal = pd.read_csv('/content/drive/MyDrive/Innovación/fetal_health.csv')

# %%
df_fetal.head()
# Out:
#    baseline value  accelerations  fetal_movement  uterine_contractions  \
# 0           120.0          0.000             0.0                 0.000
# 1           132.0          0.006             0.0                 0.006
# 2           133.0          0.003             0.0                 0.008
# 3           134.0          0.003             0.0                 0.008
# 4           132.0          0.007             0.0                 0.008
#
#    light_decelerations  severe_decelerations  prolongued_decelerations  \
# 0                0.000                   0.0                       0.0
# 1                0.003                   0.0                       0.0
# 2                0.003                   0.0                       0.0
# 3                0.003                   0.0                       0.0
# 4                0.000                   0.0                       0.0
#
#    abnormal_short_term_variability  mean_value_of_short_term_variability  \
# ...

# %% [markdown]
# #**PROBLEMA**
#
#
# ---

# %% [markdown]
# El análisis se centra en estudiar la "Tasa de natalidad entre adolescentes", específicamente para entender cómo varía este indicador en diferentes regiones de la ONU. La tasa de natalidad entre adolescentes, que mide la cantidad de nacimientos por cada 1,000 mujeres en el grupo etario de 15 a 19 años, es un indicador crucial para evaluar los desafíos y avances en la salud reproductiva juvenil.

# %%
df_data = pd.read_csv('/content/drive/MyDrive/Innovación/data.csv')

# %%
df_data.head()
# Out:
#                     Unnamed: 0 Adolescent birth rate (per 1000 women)  \
# 0                    UN Region                                   2023
# 1                        World                           1.501 41.266
# 2              Northern Africa                            1.004 40.22
# 3           Sub-Saharan Africa                           4.431 97.864
# 4  Northern America and Europe                           0.112 11.595
#
#   Adolescent birth rate (per 1000 women).1  \
# 0                                     2022
# 1                             1.535 41.841
# 2                             1.049 41.238
# 3                             4.553 99.388
# 4                             0.116 12.064
#
#   Adolescent birth rate (per 1000 women).2  \
# 0                                     2021
# 1                             1.564 42.445
# 2                             1.052 42.382
# 3                            4.728 101.003
# 4                             0.075 12.565
#
# ...

# %% [markdown]
# #**PROBLEMA**
#
#
# ---

# %% [markdown]
# Los datos están divididos por áreas de Londres llamadas distritos (existe una bandera para identificarlos), pero algunas de las variables tienen otras regiones geográficas del Reino Unido como referencia (como Inglaterra, el noreste, etc.). No se han realizado cambios en los datos, excepto por la fusión de las tablas originales en un formato más largo.

# %%
df_lon = pd.read_csv('/content/drive/MyDrive/Innovación/housing_in_london_monthly_variables.csv')

# %%
df_lon.head()
# Out:
#          date            area  average_price       code  houses_sold  \
# 0  1995-01-01  city of london          91449  E09000001         17.0
# 1  1995-02-01  city of london          82203  E09000001          7.0
# 2  1995-03-01  city of london          79121  E09000001         14.0
# 3  1995-04-01  city of london          77101  E09000001          7.0
# 4  1995-05-01  city of london          84409  E09000001         10.0
#
#    no_of_crimes  borough_flag
# 0           NaN             1
# 1           NaN             1
# 2           NaN             1
# 3           NaN             1
# 4           NaN             1

# %% [markdown]
# #**PROBLEMA**

# %% [markdown]
# Open Data BCN, proyecto que nació en 2010, implantándose el portal en 2011, ha evolucionado y ahora se enmarca en la estrategia Barcelona Ciutat Digital, fomentando una economía digital pluralista y desarrollando un nuevo modelo de innovación urbana basado en la transformación y la innovación digital del sector público y la implicación entre empresas, administraciones, mundo académico, organizaciones, comunidades y personas, con un claro liderazgo público y ciudadano.

# %%
df_bcn = pd.read_csv('/content/drive/MyDrive/Innovación/accidents_2017.csv')

# %%
df_bcn.head()
# Out:
#                 Id District Name           Neighborhood Name  \
# 0  2017S008429           Unknown                     Unknown
# 1  2017S007316           Unknown                     Unknown
# 2  2017S010210           Unknown                     Unknown
# 3  2017S006364           Unknown                     Unknown
# 4  2017S004615        Sant Martí  el Camp de l'Arpa del Clot
#
#                                               Street   Weekday      Month  \
# 0  Número 27                                     ...    Friday    October
# 1  Número 3 Zona Franca / Número 50 Zona Franca  ...    Friday  September
# 2  Litoral (Besòs)                               ...    Friday   December
# 3  Número 3 Zona Franca                          ...    Friday       July
# 4  Las Navas de Tolosa                           ...  Thursday        May
#
#    Day  Hour Part of the day  Mild injuries  Serious injuries  Victims  \
# 0   13     8         Morning              2                 0        2
# ...

# %% [markdown]
# #**PROBLEMA**

# %% [markdown]
# El Índice de Percepción de la Corrupción (IPC) es el ranking de corrupción global más utilizado en el mundo. Mide cuán corrupto se percibe el sector público de cada país, según expertos y empresarios. La puntuación de cada país es una combinación de al menos 3 fuentes de datos extraídas de 13 encuestas y evaluaciones de corrupción diferentes. Estas fuentes de datos son recopiladas por una variedad de instituciones de buena reputación, incluyendo el Banco Mundial y el Foro Económico Mundial.

# %%
df_corrup = pd.read_csv('/content/drive/MyDrive/Innovación/transparency_active.csv')

# %%
df_corrup.head()
# Out:
#    Unnamed: 0      country iso3 region  year  score   rank  sources  \
# 0           0  Afghanistan  AFG     AP  2021   16.0  174.0      5.0
# 1           1  Afghanistan  AFG     AP  2020   19.0  165.0      5.0
# 2           2  Afghanistan  AFG     AP  2019   16.0  173.0      5.0
# 3           3  Afghanistan  AFG     AP  2018   16.0  172.0      5.0
# 4           4  Afghanistan  AFG     AP  2017   15.0  177.0      5.0
#
#    standardError
# 0           2.12
# 1           2.44
# 2           2.55
# 3           1.41
# 4           1.39

# %% [markdown]
# # PROBLEMA

# %% [markdown]
# El Observatorio Espacial Kepler es un satélite construido por la NASA que se lanzó en 2009. El telescopio está dedicado a la búsqueda de exoplanetas en sistemas estelares además del nuestro, con el objetivo final de encontrar posiblemente otros planetas habitables además del nuestro. La misión original terminó en 2013 debido a fallas mecánicas, pero el telescopio ha estado funcional desde 2014 en una misión extendida "K2". Kepler había verificado 1284 nuevos exoplanetas a partir de mayo de 2016. Desde octubre de 2017, hay más de 3000 exoplanetas confirmados en total (utilizando todos los métodos de detección, incluidos los terrestres). El telescopio todavía está activo y continúa recopilando nuevos datos sobre su misión extendida.

# %%
df_nasa = pd.read_csv('/content/drive/MyDrive/Innovación/cumulative.csv.zip')

# %%
df_nasa.head()
# Out:
#    rowid     kepid kepoi_name   kepler_name koi_disposition koi_pdisposition  \
# 0      1  10797460  K00752.01  Kepler-227 b       CONFIRMED        CANDIDATE
# 1      2  10797460  K00752.02  Kepler-227 c       CONFIRMED        CANDIDATE
# 2      3  10811496  K00753.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 3      4  10848459  K00754.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 4      5  10854555  K00755.01  Kepler-664 b       CONFIRMED        CANDIDATE
#
#    koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0      1.000              0              0              0              0
# 1      0.969              0              0              0              0
# 2      0.000              0              1              0              0
# 3      0.000              0              1              0              0
# 4      1.000              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# ...
